# %% [markdown]
# ## This notebook only demonstrates how to use feature engineering

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_train=pd.read_csv("C:\\Users\\lenovo\\Downloads\\train.csv\\train.csv")
df_test=pd.read_csv("C:\\Users\\lenovo\\Downloads\\test.csv\\test.csv")

# %%
df_train
# Out:
#             id  CustomerId         Surname  CreditScore Geography  Gender  \
# 0            0    15674932  Okwudilichukwu          668    France    Male
# 1            1    15749177   Okwudiliolisa          627    France    Male
# 2            2    15694510           Hsueh          678    France    Male
# 3            3    15741417             Kao          581    France    Male
# 4            4    15766172       Chiemenam          716     Spain    Male
# ...        ...         ...             ...          ...       ...     ...
# 165029  165029    15667085            Meng          667     Spain  Female
# 165030  165030    15665521       Okechukwu          792    France    Male
# 165031  165031    15664752            Hsia          565    France    Male
# 165032  165032    15689614          Hsiung          554     Spain  Female
# 165033  165033    15732798         Ulyanov          850    France    Male
#
#          Age  Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df_train.isnull().sum()
# Out:
# id                 0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
df_train.duplicated().sum()
# Out:
# 0

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165034 entries, 0 to 165033
# Data columns (total 14 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   id               165034 non-null  int64
#  1   CustomerId       165034 non-null  int64
#  2   Surname          165034 non-null  object
#  3   CreditScore      165034 non-null  int64
#  4   Geography        165034 non-null  object
#  5   Gender           165034 non-null  object
#  6   Age              165034 non-null  float64
#  7   Tenure           165034 non-null  int64
#  8   Balance          165034 non-null  float64
#  9   NumOfProducts    165034 non-null  int64
#  10  HasCrCard        165034 non-null  float64
#  11  IsActiveMember   165034 non-null  float64
#  12  EstimatedSalary  165034 non-null  float64
#  13  Exited           165034 non-null  int64
# dtypes: float64(5), int64(6), object(3)
# memory usage: 17.6+ MB

# %%
df_train.describe()
# Out:
#                 id    CustomerId    CreditScore            Age         Tenure  \
# count  165034.0000  1.650340e+05  165034.000000  165034.000000  165034.000000
# mean    82516.5000  1.569201e+07     656.454373      38.125888       5.020353
# std     47641.3565  7.139782e+04      80.103340       8.867205       2.806159
# min         0.0000  1.556570e+07     350.000000      18.000000       0.000000
# 25%     41258.2500  1.563314e+07     597.000000      32.000000       3.000000
# 50%     82516.5000  1.569017e+07     659.000000      37.000000       5.000000
# 75%    123774.7500  1.575682e+07     710.000000      42.000000       7.000000
# max    165033.0000  1.581569e+07     850.000000      92.000000      10.000000
#
#              Balance  NumOfProducts      HasCrCard  IsActiveMember  \
# count  165034.000000  165034.000000  165034.000000   165034.000000
# mean    55478.086689       1.554455       0.753954        0.497770
# ...

# %%
df_train.drop(columns=['id','CustomerId','Surname'],inplace=True)

# %%
from sklearn.preprocessing import StandardScaler,OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split

# %%
x=df_train.iloc[:,:-1]
x
# Out:
#         CreditScore Geography  Gender   Age  Tenure    Balance  NumOfProducts  \
# 0               668    France    Male  33.0       3       0.00              2
# 1               627    France    Male  33.0       1       0.00              2
# 2               678    France    Male  40.0      10       0.00              2
# 3               581    France    Male  34.0       2  148882.54              1
# 4               716     Spain    Male  33.0       5       0.00              2
# ...             ...       ...     ...   ...     ...        ...            ...
# 165029          667     Spain  Female  33.0       2       0.00              1
# 165030          792    France    Male  35.0       3       0.00              1
# 165031          565    France    Male  31.0       5       0.00              1
# 165032          554     Spain  Female  30.0       7  161533.00              1
# 165033          850    France    Male  31.0       1       0.00              1
#
# ...

# %%
y=df_train.iloc[:,-1]
y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 165029    0
# 165030    0
# 165031    0
# 165032    0
# 165033    1
# Name: Exited, Length: 165034, dtype: int64

# %% [markdown]
# ### Encoding using Sklearn

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.2)

# %%
transformer=ColumnTransformer(transformers=[
    ('tnf1',StandardScaler(),['CreditScore','Age','Tenure','Balance','NumOfProducts','EstimatedSalary']),
    ('tnf2',OneHotEncoder(),['Geography','Gender']),   
])

# %%
x_train
# Out:
#         CreditScore Geography  Gender   Age  Tenure    Balance  NumOfProducts  \
# 149380          679    France    Male  41.0       9       0.00              2
# 164766          721    France    Male  46.0       9  115764.32              2
# 155569          551    France    Male  35.0       5       0.00              1
# 124304          743     Spain  Female  31.0       3   57866.03              2
# 108008          675    France    Male  28.0       2       0.00              2
# ...             ...       ...     ...   ...     ...        ...            ...
# 119879          668   Germany    Male  45.0       6  104576.80              1
# 103694          751    France    Male  43.0       7       0.00              2
# 131932          753    France  Female  39.0       7       0.00              2
# 146867          685    France  Female  48.0       4       0.00              2
# 121958          667   Germany    Male  35.0       1  135637.00              1
#
# ...

# %%
x_train=transformer.fit_transform(x_train)
x_train
# Out:
# array([[ 0.2775534 ,  0.32458613,  1.41649004, ...,  0.        ,
#          0.        ,  1.        ],
#        [ 0.80227227,  0.88829874,  1.41649004, ...,  0.        ,
#          0.        ,  1.        ],
#        [-1.32158984, -0.35186899, -0.0077698 , ...,  0.        ,
#          0.        ,  1.        ],
#        ...,
#        [ 1.20205808,  0.09910109,  0.70436012, ...,  0.        ,
#          1.        ,  0.        ],
#        [ 0.35251324,  1.11378378, -0.36383476, ...,  0.        ,
#          1.        ,  0.        ],
#        [ 0.12763372, -0.35186899, -1.43202963, ...,  0.        ,
#          0.        ,  1.        ]])

# %%
x_test=transformer.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,classification_report, confusion_matrix

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

print("Classification Report:")
print(classification_report(y_test, y_pred))

print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 0.8163722846668888
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.95      0.89     26052
#            1       0.63      0.30      0.41      6955
#
#     accuracy                           0.82     33007
#    macro avg       0.74      0.63      0.65     33007
# weighted avg       0.79      0.82      0.79     33007
#
# Confusion Matrix:
# [[24835  1217]
#  [ 4844  2111]]

# %% [markdown]
# ### OHE using Pandas

# %%
pd.get_dummies(df_train,columns=['Geography','Gender'],drop_first=True,dtype=int)
# Out:
#         CreditScore   Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0               668  33.0       3       0.00              2        1.0
# 1               627  33.0       1       0.00              2        1.0
# 2               678  40.0      10       0.00              2        1.0
# 3               581  34.0       2  148882.54              1        1.0
# 4               716  33.0       5       0.00              2        1.0
# ...             ...   ...     ...        ...            ...        ...
# 165029          667  33.0       2       0.00              1        1.0
# 165030          792  35.0       3       0.00              1        0.0
# 165031          565  31.0       5       0.00              1        1.0
# 165032          554  30.0       7  161533.00              1        0.0
# 165033          850  31.0       1       0.00              1        1.0
#
#         IsActiveMember  EstimatedSalary  Exited  Geography_Germany  \
# ...

# %% [markdown]
# ### Encoding using map() function

# %%
mapping = {'Male': 0, 'Female': 1}

# Apply the mapping using the map() function
df_train['Gender_encoded'] = df_train['Gender'].map(mapping)
df_train
# Out:
#         CreditScore Geography  Gender   Age  Tenure    Balance  NumOfProducts  \
# 0               668    France    Male  33.0       3       0.00              2
# 1               627    France    Male  33.0       1       0.00              2
# 2               678    France    Male  40.0      10       0.00              2
# 3               581    France    Male  34.0       2  148882.54              1
# 4               716     Spain    Male  33.0       5       0.00              2
# ...             ...       ...     ...   ...     ...        ...            ...
# 165029          667     Spain  Female  33.0       2       0.00              1
# 165030          792    France    Male  35.0       3       0.00              1
# 165031          565    France    Male  31.0       5       0.00              1
# 165032          554     Spain  Female  30.0       7  161533.00              1
# 165033          850    France    Male  31.0       1       0.00              1
#
# ...

# %% [markdown]
# ### Encoding without Column Transfers

# %%
ohe=OneHotEncoder(drop='first',sparse=False)

# %%
# Reshape 'Geography' column to a 2D array-like object
geography_2d = df_new[['Geography','Gender']].values 
a = ohe.fit_transform(geography_2d)
a.shape
# Out:
# C:\Users\lenovo\New folder\lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# (165034, 3)

# %%
tp=df_new[['CreditScore','Age','Balance','IsActiveMember','EstimatedSalary']].values
tp
# Out:
# array([[6.6800000e+02, 3.3000000e+01, 0.0000000e+00, 0.0000000e+00,
#         1.8144997e+05],
#        [6.2700000e+02, 3.3000000e+01, 0.0000000e+00, 1.0000000e+00,
#         4.9503500e+04],
#        [6.7800000e+02, 4.0000000e+01, 0.0000000e+00, 0.0000000e+00,
#         1.8486669e+05],
#        ...,
#        [5.6500000e+02, 3.1000000e+01, 0.0000000e+00, 1.0000000e+00,
#         1.2742956e+05],
#        [5.5400000e+02, 3.0000000e+01, 1.6153300e+05, 1.0000000e+00,
#         7.1173030e+04],
#        [8.5000000e+02, 3.1000000e+01, 0.0000000e+00, 0.0000000e+00,
#         6.1581790e+04]])

# %%
sd=StandardScaler()
b=sd.fit_transform(tp)
b.shape
# Out:
# (165034, 5)

# %%
c=df_new[['Tenure','NumOfProducts','HasCrCard','IsActiveMember']].values
c.shape
# Out:
# (165034, 4)

# %%
import numpy as np

# %%
encoded_df=np.hstack((a,b,c))
encoded_df.shape
# Out:
# (165034, 12)

# %% [markdown]
# ##### Now this will be our X_train new
